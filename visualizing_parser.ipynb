# %%
import pandas as pd
import pickle
with open('table.pkl', 'rb') as file:
    table = pickle.load(file)
    
table_df = pd.DataFrame(table).T
table_df = table_df.replace('empty','')
table_df
# Out:
#                                       $                       (  \
# ASSIGNMENT                         sync
# DECLARATION                        sync
# EXPRESSION
# FACTOR                                   FACTOR->( EXPRESSION )
# IF                                 sync
# METHOD_BODY                        sync
# PRIMITIVE_TYPE
# SIGN
# SIMPLE_EXPRESSION
# SIMPLE_EXPRESSION1
# STATEMENT                          sync
# STATEMENT_LIST                     sync
# STATEMENT_LIST0     STATEMENT_LIST0->\L
# TERM
# TERM2
# WHILE                              sync
#
#                                          )        +        - ; =  \
# ASSIGNMENT
# DECLARATION
# EXPRESSION                            sync
# FACTOR                                sync
# IF
# METHOD_BODY
# PRIMITIVE_TYPE
# SIGN                                        SIGN->+  SIGN->-
# SIMPLE_EXPRESSION                     sync
# SIMPLE_EXPRESSION1  SIMPLE_EXPRESSION1->\L
# STATEMENT
# STATEMENT_LIST
# STATEMENT_LIST0
# TERM                                  sync
# TERM2                            TERM2->\L
# WHILE
#
#                                                                 addop else  \
# ASSIGNMENT
# DECLARATION
# EXPRESSION
# FACTOR                                                           sync
# IF
# METHOD_BODY
# PRIMITIVE_TYPE
# SIGN
# SIMPLE_EXPRESSION
# SIMPLE_EXPRESSION1  SIMPLE_EXPRESSION1->addop TERM SIMPLE_EXPRESSION1
# STATEMENT
# STATEMENT_LIST
# STATEMENT_LIST0
# TERM                                                             sync
# TERM2                                                       TERM2->\L
# WHILE
#
#                                                                 float  \
# ASSIGNMENT                                                       sync
# DECLARATION                          DECLARATION->PRIMITIVE_TYPE id ;
# EXPRESSION          EXPRESSION->SIMPLE_EXPRESSIONSIMPLE_EXPRESSION...
# FACTOR
# IF                                                               sync
# METHOD_BODY                               METHOD_BODY->STATEMENT_LIST
# PRIMITIVE_TYPE                                  PRIMITIVE_TYPE->float
# SIGN                                                             sync
# SIMPLE_EXPRESSION   SIMPLE_EXPRESSION->TERM SIMPLE_EXPRESSION1SIGN...
# SIMPLE_EXPRESSION1
# STATEMENT                                      STATEMENT->DECLARATION
# STATEMENT_LIST              STATEMENT_LIST->STATEMENT STATEMENT_LIST0
# STATEMENT_LIST0            STATEMENT_LIST0->STATEMENT STATEMENT_LIST0
# TERM                                               TERM->FACTOR TERM2
# TERM2
# WHILE                                                            sync
#
#                                        id  \
# ASSIGNMENT                 ASSIGNMENT->id
# DECLARATION
# EXPRESSION
# FACTOR                         FACTOR->id
# IF
# METHOD_BODY
# PRIMITIVE_TYPE                       sync
# SIGN
# SIMPLE_EXPRESSION
# SIMPLE_EXPRESSION1
# STATEMENT           STATEMENT->ASSIGNMENT
# STATEMENT_LIST
# STATEMENT_LIST0
# TERM
# TERM2
# WHILE
#
#                                                                    if  \
# ASSIGNMENT
# DECLARATION
# EXPRESSION
# FACTOR
# IF                  IF->if ( EXPRESSION ) { STATEMENT } else { STA...
# METHOD_BODY
# PRIMITIVE_TYPE
# SIGN
# SIMPLE_EXPRESSION
# SIMPLE_EXPRESSION1
# STATEMENT                                               STATEMENT->IF
# STATEMENT_LIST
# STATEMENT_LIST0
# TERM
# TERM2
# WHILE
#
#                                                                   int  \
# ASSIGNMENT                                                       sync
# DECLARATION                          DECLARATION->PRIMITIVE_TYPE id ;
# EXPRESSION          EXPRESSION->SIMPLE_EXPRESSIONSIMPLE_EXPRESSION...
# FACTOR
# IF                                                               sync
# METHOD_BODY                               METHOD_BODY->STATEMENT_LIST
# PRIMITIVE_TYPE                                    PRIMITIVE_TYPE->int
# SIGN                                                             sync
# SIMPLE_EXPRESSION   SIMPLE_EXPRESSION->TERM SIMPLE_EXPRESSION1SIGN...
# SIMPLE_EXPRESSION1
# STATEMENT                                      STATEMENT->DECLARATION
# STATEMENT_LIST              STATEMENT_LIST->STATEMENT STATEMENT_LIST0
# STATEMENT_LIST0            STATEMENT_LIST0->STATEMENT STATEMENT_LIST0
# TERM                                               TERM->FACTOR TERM2
# TERM2
# WHILE                                                            sync
#
#                                         mulop          num  \
# ASSIGNMENT
# DECLARATION
# EXPRESSION
# FACTOR                                   sync  FACTOR->num
# IF
# METHOD_BODY
# PRIMITIVE_TYPE
# SIGN
# SIMPLE_EXPRESSION
# SIMPLE_EXPRESSION1
# STATEMENT
# STATEMENT_LIST
# STATEMENT_LIST0
# TERM
# TERM2               TERM2->mulop FACTOR TERM2
# WHILE
#
#                                      relop  \
# ASSIGNMENT
# DECLARATION
# EXPRESSION
# FACTOR                                sync
# IF
# METHOD_BODY
# PRIMITIVE_TYPE
# SIGN
# SIMPLE_EXPRESSION                     sync
# SIMPLE_EXPRESSION1  SIMPLE_EXPRESSION1->\L
# STATEMENT
# STATEMENT_LIST
# STATEMENT_LIST0
# TERM                                  sync
# TERM2                            TERM2->\L
# WHILE
#
#                                                         while {     }
# ASSIGNMENT                                                       sync
# DECLARATION                                                      sync
# EXPRESSION
# FACTOR
# IF                                                               sync
# METHOD_BODY
# PRIMITIVE_TYPE
# SIGN
# SIMPLE_EXPRESSION
# SIMPLE_EXPRESSION1
# STATEMENT                                    STATEMENT->WHILE    sync
# STATEMENT_LIST
# STATEMENT_LIST0
# TERM
# TERM2
# WHILE               WHILE->while ( EXPRESSION ) { STATEMENT }    sync
